# %% [markdown]
# <a href="https://colab.research.google.com/github/HowardHNguyen/Python/blob/main/Data_Manipulation_Samples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame()
df2 = pd.DataFrame()

# %%
df1['viewers'] = ["Sushmita", "Adam", "Benny", "Anurag"]
df2['users'] = ["Adam", "Anurag", "Benny", "Sushmita", "Apoorva"]

# %%
df1 = df1.assign(views = [31.2,17.9,265.23,42.47])
df2 = df2.assign(cost = [20,np.nan, 15, 2, 7])

# %%
df1.head()
# Out:
#     viewers   views
# 0  Sushmita   31.20
# 1      Adam   17.90
# 2     Benny  265.23
# 3    Anurag   42.47

# %%
df2.head()
# Out:
#       users  cost
# 0      Adam  20.0
# 1    Anurag   NaN
# 2     Benny  15.0
# 3  Sushmita   2.0
# 4   Apoorva   7.0

# %%
df = df1.merge(df2, left_on="viewers", right_on="users", how="left")
df.head()
# Out:
#     viewers   views     users  cost
# 0  Sushmita   31.20  Sushmita   2.0
# 1      Adam   17.90      Adam  20.0
# 2     Benny  265.23     Benny  15.0
# 3    Anurag   42.47    Anurag   NaN

# %%
df=df.fillna(df.mean())
# Out:
# <ipython-input-8-6f8c6f28e805>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df=df.fillna(df.mean())

# %%
df['Gender'] = ["Female", "Male", "Male", "Female"]

# %%
df
# Out:
#     viewers   views     users       cost  Gender
# 0  Sushmita   31.20  Sushmita   2.000000  Female
# 1      Adam   17.90      Adam  20.000000    Male
# 2     Benny  265.23     Benny  15.000000    Male
# 3    Anurag   42.47    Anurag  12.333333  Female

# %%
df['Gender']=df['Gender'].map({"Female":"F","Male":"M"})

# %%
df
# Out:
#     viewers   views     users       cost Gender
# 0  Sushmita   31.20  Sushmita   2.000000      F
# 1      Adam   17.90      Adam  20.000000      M
# 2     Benny  265.23     Benny  15.000000      M
# 3    Anurag   42.47    Anurag  12.333333      F

# %%
df.groupby('Gender')['cost'].sum()
# Out:
# Gender
# F    14.333333
# M    35.000000
# Name: cost, dtype: float64

# %%
df.set_index(['viewers'], inplace = True)

# %%
df.head()
# Out:
#            views     users       cost Gender
# viewers
# Sushmita   31.20  Sushmita   2.000000      F
# Adam       17.90      Adam  20.000000      M
# Benny     265.23     Benny  15.000000      M
# Anurag     42.47    Anurag  12.333333      F

# %%
# to find the cost of acquisition of Adam and Anurag along w/ their cost and views: use the loc function
df.loc[['Adam','Anurag'],['cost','views']]
# Out:
#               cost  views
# viewers
# Adam     20.000000  17.90
# Anurag   12.333333  42.47

# %%
# Creating new DataFrames: You typically use the DataFrame function to create
# a completely new DataFrame. The function directly converts a Python object
# into a pandas DataFrame. The DataFrame function in general works with any
# iterable collection of data, such as dict and list. You can also pass an empty
# collection or a singleton collection to it.
df=pd.DataFrame({'Currency': pd.Series(['USD','EUR','GBP']),'ValueInINR': pd.Series([70, 89, 99])})

df.head()
# Out:
#   Currency  ValueInINR
# 0      USD          70
# 1      EUR          89
# 2      GBP          99

# %%
import copy
df1 = df.copy(deep=True)

# %%
df1.head()
# Out:
#   Currency  ValueInINR
# 0      USD          70
# 1      EUR          89
# 2      GBP          99

# %%
# df.drop(labels, axis): This method removes the rows or columns
# specified by the labels and corresponding axis, or those specified by the index or
# column names directly.
df.drop(['Currency'],axis=1)
# Out:
#    ValueInINR
# 0          70
# 1          89
# 2          99

# %%
pd.DataFrame.from_dict({'Currency': ['USD','EUR','GBP'],'ValueInINR':[70, 89, 99]})
# Out:
#   Currency  ValueInINR
# 0      USD          70
# 1      EUR          89
# 2      GBP          99
